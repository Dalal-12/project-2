# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
weather = pd.read_csv('/Users/dalal/Desktop/project-2/weather.csv')
weather
# Out:
#         Unnamed: 0    city            date   time  year  month  day  hour  \
# 0                0  Qassim  1 January 2017  00:00  2017      1    1    24
# 1                1  Qassim  1 January 2017  01:00  2017      1    1     1
# 2                2  Qassim  1 January 2017  03:00  2017      1    1     3
# 3                3  Qassim  1 January 2017  04:00  2017      1    1     4
# 4                4  Qassim  1 January 2017  05:00  2017      1    1     5
# ...            ...     ...             ...    ...   ...    ...  ...   ...
# 249018        2848    Jawf   30 April 2019  19:00  2019      4   30    19
# 249019        2849    Jawf   30 April 2019  20:00  2019      4   30    20
# 249020        2850    Jawf   30 April 2019  21:00  2019      4   30    21
# 249021        2851    Jawf   30 April 2019  22:00  2019      4   30    22
# 249022        2852    Jawf   30 April 2019  23:00  2019      4   30    23
#
#         minute          weather  temp  wind humidity  barometer  visibility
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249023 entries, 0 to 249022
# Data columns (total 15 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  249023 non-null  int64
#  1   city        249023 non-null  object
#  2   date        249023 non-null  object
#  3   time        249023 non-null  object
#  4   year        249023 non-null  int64
#  5   month       249023 non-null  int64
#  6   day         249023 non-null  int64
#  7   hour        249023 non-null  int64
#  8   minute      249023 non-null  int64
#  9   weather     249023 non-null  object
#  10  temp        249023 non-null  int64
#  11  wind        249023 non-null  int64
#  12  humidity    249006 non-null  object
#  13  barometer   248951 non-null  float64
#  14  visibility  249023 non-null  int64
# dtypes: float64(1), int64(9), object(5)
# memory usage: 28.5+ MB

# %%
weather.describe().round(2)
# Out:
#        Unnamed: 0       year      month        day       hour     minute  \
# count   249023.00  249023.00  249023.00  249023.00  249023.00  249023.00
# mean    121690.69    2017.71       6.05      15.69      12.54       0.13
# std      71831.55       0.71       3.52       8.79       6.91       1.97
# min          0.00    2017.00       1.00       1.00       1.00       0.00
# 25%      59402.50    2017.00       3.00       8.00       7.00       0.00
# 50%     121658.00    2018.00       6.00      16.00      13.00       0.00
# 75%     183913.50    2018.00       9.00      23.00      19.00       0.00
# max     246169.00    2019.00      12.00      31.00      24.00      59.00
#
#             temp       wind  barometer  visibility
# count  249023.00  249023.00  248951.00   249023.00
# mean       24.72      12.96    1015.46       11.05
# std         8.88       8.71       6.97        7.05
# min        -4.00      -1.00     904.00       -1.00
# 25%        18.00       7.00    1011.00        5.00
# ...

# %%
weather[['temp','wind']].describe().round(2)
# Out:
#             temp       wind
# count  249023.00  249023.00
# mean       24.72      12.96
# std         8.88       8.71
# min        -4.00      -1.00
# 25%        18.00       7.00
# 50%        24.00      11.00
# 75%        31.00      19.00
# max        50.00     163.00

# %%
weather['date'] = pd.to_datetime(weather['date'], format='%d %B %Y')

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249023 entries, 0 to 249022
# Data columns (total 15 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  249023 non-null  int64
#  1   city        249023 non-null  object
#  2   date        249023 non-null  datetime64[ns]
#  3   time        249023 non-null  object
#  4   year        249023 non-null  int64
#  5   month       249023 non-null  int64
#  6   day         249023 non-null  int64
#  7   hour        249023 non-null  int64
#  8   minute      249023 non-null  int64
#  9   weather     249023 non-null  object
#  10  temp        249023 non-null  int64
#  11  wind        249023 non-null  int64
#  12  humidity    249006 non-null  object
#  13  barometer   248951 non-null  float64
#  14  visibility  249023 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(9), object(4)
# memory usage: 28.5+ MB

# %%
weather.drop(['Unnamed: 0','year','month','day','hour','minute'], axis=1, inplace=True)

# %%
weather.head()
# Out:
#      city       date   time weather  temp  wind humidity  barometer  \
# 0  Qassim 2017-01-01  00:00  Clear     17    11      64%     1018.0
# 1  Qassim 2017-01-01  01:00  Clear     17     6      64%     1018.0
# 2  Qassim 2017-01-01  03:00  Clear     15    11      72%     1019.0
# 3  Qassim 2017-01-01  04:00  Clear     15    11      72%     1019.0
# 4  Qassim 2017-01-01  05:00  Clear     15     9      72%     1019.0
#
#    visibility
# 0          16
# 1          16
# 2          16
# 3          16
# 4          16

# %%
weather.tail()
# Out:
#         city       date   time          weather  temp  wind humidity  \
# 249018  Jawf 2019-04-30  19:00  Passing clouds     32    19      14%
# 249019  Jawf 2019-04-30  20:00  Passing clouds     29     9      22%
# 249020  Jawf 2019-04-30  21:00  Passing clouds     27     7      24%
# 249021  Jawf 2019-04-30  22:00           Clear     26     0      26%
# 249022  Jawf 2019-04-30  23:00           Clear     24     7      29%
#
#         barometer  visibility
# 249018     1014.0          -1
# 249019     1015.0          -1
# 249020     1016.0          -1
# 249021     1017.0          16
# 249022     1017.0          16

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249023 entries, 0 to 249022
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   city        249023 non-null  object
#  1   date        249023 non-null  datetime64[ns]
#  2   time        249023 non-null  object
#  3   weather     249023 non-null  object
#  4   temp        249023 non-null  int64
#  5   wind        249023 non-null  int64
#  6   humidity    249006 non-null  object
#  7   barometer   248951 non-null  float64
#  8   visibility  249023 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 17.1+ MB

# %%
weather['time'] = pd.to_datetime(weather['time'])
weather['time'] = weather['time'].dt.strftime('%H')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\dateutil\parser\_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File ~\anaconda3\Lib\site-packages\dateutil\parser\_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: day is out of range for month
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\_libs\tslib.pyx:605, in pandas._libs.tslib.array_to_datetime()
#
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249023 entries, 0 to 249022
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   city        249023 non-null  object
#  1   date        249023 non-null  datetime64[ns]
#  2   time        249023 non-null  object
#  3   weather     249023 non-null  object
#  4   temp        249023 non-null  int64
#  5   wind        249023 non-null  int64
#  6   humidity    249006 non-null  object
#  7   barometer   248951 non-null  float64
#  8   visibility  249023 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 17.1+ MB

# %%
weather.head(15)
# Out:
#       city       date time weather  temp  wind humidity  barometer  visibility
# 0   Qassim 2017-01-01   00  Clear     17    11      64%     1018.0          16
# 1   Qassim 2017-01-01   01  Clear     17     6      64%     1018.0          16
# 2   Qassim 2017-01-01   03  Clear     15    11      72%     1019.0          16
# 3   Qassim 2017-01-01   04  Clear     15    11      72%     1019.0          16
# 4   Qassim 2017-01-01   05  Clear     15     9      72%     1019.0          16
# 5   Qassim 2017-01-01   06  Clear     13    13      82%     1019.0          16
# 6   Qassim 2017-01-01   07  Sunny     12     7      88%     1019.0          16
# 7   Qassim 2017-01-01   08  Sunny     14     9      72%     1021.0          16
# 8   Qassim 2017-01-01   09  Sunny     15     9      72%     1021.0           7
# 9   Qassim 2017-01-01   10  Sunny     17     7      64%     1021.0           9
# 10  Qassim 2017-01-01   11  Sunny     19    19      64%     1021.0           7
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249023 entries, 0 to 249022
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   city        249023 non-null  object
#  1   date        249023 non-null  datetime64[ns]
#  2   time        249023 non-null  object
#  3   weather     249023 non-null  object
#  4   temp        249023 non-null  int64
#  5   wind        249023 non-null  int64
#  6   humidity    249006 non-null  object
#  7   barometer   248951 non-null  float64
#  8   visibility  249023 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 17.1+ MB

# %%
weather.head()
# Out:
#      city       date time weather  temp  wind humidity  barometer  visibility
# 0  Qassim 2017-01-01   00  Clear     17    11      64%     1018.0          16
# 1  Qassim 2017-01-01   01  Clear     17     6      64%     1018.0          16
# 2  Qassim 2017-01-01   03  Clear     15    11      72%     1019.0          16
# 3  Qassim 2017-01-01   04  Clear     15    11      72%     1019.0          16
# 4  Qassim 2017-01-01   05  Clear     15     9      72%     1019.0          16
